# %%
import numpy as np
import pandas as pd
from pandas_datareader import data as wb
import matplotlib.pyplot as plt

# %%
tickers = ['^GSPC', '^IXIC', '^GDAXI']

ind_data = pd.DataFrame()

for t in tickers:
    ind_data[t] = wb.DataReader(t, data_source='yahoo', start='1997-1-1')['Adj Close']

# %%
ind_data.head()
# Out:
#                  ^GSPC        ^IXIC       ^GDAXI
# Date
# 1997-01-02  737.010010  1280.699951  2820.810059
# 1997-01-03  748.030029  1310.680054  2863.260010
# 1997-01-06  747.650024  1316.400024  2890.199951
# 1997-01-07  753.229980  1327.729980  2876.340088
# 1997-01-08  748.409973  1320.349976  2904.080078

# %%
ind_data.tail()
# Out:
#                   ^GSPC        ^IXIC        ^GDAXI
# Date
# 2020-02-03  3248.919922  9273.400391  13045.190430
# 2020-02-04  3297.590088  9467.969727  13281.740234
# 2020-02-05  3334.689941  9508.679688  13478.330078
# 2020-02-06  3345.780029  9572.150391  13574.820312
# 2020-02-07  3336.969971  9550.219727  13492.530273

# %%
(ind_data / ind_data.iloc[0] * 100).plot(figsize=(15,6));
plt.show()

# %%
ind_returns = (ind_data / ind_data.shift(1)) - 1

ind_returns.tail()
# Out:
#                ^GSPC     ^IXIC    ^GDAXI
# Date
# 2020-02-03  0.007255  0.013382  0.004870
# 2020-02-04  0.014980  0.020981  0.018133
# 2020-02-05  0.011251  0.004300  0.014802
# 2020-02-06  0.003326  0.006675  0.007159
# 2020-02-07 -0.002633 -0.002291 -0.006062

# %%
annual_ind_returns = ind_returns.mean() * 250
annual_ind_returns
# Out:
# ^GSPC     0.082593
# ^IXIC     0.116714
# ^GDAXI    0.079748
# dtype: float64

# %%
tickers = ['PG', '^GSPC', '^DJI']

data_2 = pd.DataFrame()

for t in tickers:
    data_2[t] = wb.DataReader(t, data_source='yahoo', start='2007-1-1')['Adj Close']

# %%
data_2.tail()
# Out:
#                     PG        ^GSPC          ^DJI
# Date
# 2020-02-03  125.110001  3248.919922  28399.810547
# 2020-02-04  125.660004  3297.590088  28807.630859
# 2020-02-05  126.809998  3334.689941  29290.849609
# 2020-02-06  127.139999  3345.780029  29379.769531
# 2020-02-07  126.959999  3337.360107  29197.560547

# %%
(data_2 / data_2.iloc[0] * 100).plot(figsize=(15,6));
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
